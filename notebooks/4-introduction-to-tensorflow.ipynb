# %%
import tensorflow as tf

# %%
x = tf.placeholder(dtype=tf.float32)

# %%
y = tf.pow((2 * x), 2) + (2 * x) + 1

# %%
init_op = tf.global_variables_initializer()

# %%
sess = tf.Session()

# %%
sess.run(init_op)

# %%
value = sess.run(y, feed_dict={x: 10})

# %%
print(value)
# Out:
# 421.0

# %%
weights = tf.Variable(tf.random_normal(shape=[10]))

# %%
sess.run(tf.global_variables_initializer())

# %%
sess.run(weights)
# Out:
# array([-0.34563982,  0.38968664,  0.2016294 ,  0.67609346, -1.364591  ,
#        -1.1950035 ,  0.3150586 , -0.56542975,  0.90643066,  0.8813415 ],
#       dtype=float32)
